# %%
import os

print(os.getcwd())
# Out:
# c:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\notebooks

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles and Folders:")
for item in os.listdir():
    print(item)
# Out:
# Current Directory:
# c:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\notebooks
#
# Files and Folders:
# 01_data_understanding.ipynb

# %%
import os

files = os.listdir("../data/raw")

print("Number of files:", len(files))

for file in files:
    print(file)
# Out:
# Number of files: 8
# AddrAddr_edgelist.csv
# AddrTx_edgelist.csv
# TxAddr_edgelist.csv
# txs_classes.csv
# txs_edgelist.csv
# txs_features.csv
# wallets_classes.csv
# wallets_features_classes_combined.csv

# %%
import pandas as pd

tx_features = pd.read_csv(
    r"C:\Users\asus\Downloads\Elliptic++ Dataset\txs_features.csv",
    nrows=5
)

print(tx_features.shape)
display(tx_features.head())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\notebooks\01_data_understanding.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Desktop/Elliptic%2B%2B%20%20project/Elliptic_Fraud_Detection/notebooks/01_data_understanding.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/asus/Desktop/Elliptic%2B%2B%20%20project/Elliptic_Fraud_Detection/notebooks/01_data_understanding.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> tx_features = pd.read_csv(
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Desktop/Elliptic%2B%2B%20%20project/Elliptic_Fraud_Detection/notebooks/01_data_understanding.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     r"C:\Users\asus\Downloads\Elliptic++ Dataset\txs_features.csv",
# ...

# %%
import os

path = r"C:\Users\asus\Downloads\Elliptic++ Dataset"

print("Exists:", os.path.exists(path))
print("Is File:", os.path.isfile(path))
print("Is Directory:", os.path.isdir(path))

if os.path.isdir(path):
    print("\nContents:")
    print(os.listdir(path)[:20])
# Out:
# Exists: True
# Is File: False
# Is Directory: True
#
# Contents:
# ['AddrTx_edgelist.csv', 'TxAddr_edgelist.csv', 'txs_classes.csv', 'txs_edgelist.csv', 'txs_features.csv', 'wallets_classes.csv', 'wallets_features.csv', 'wallets_features_classes_combined.csv']

# %%
import os

folder = r"C:\Users\asus\Downloads\Elliptic++ Dataset"

for file in os.listdir(folder):
    print(file)
# Out:
# AddrTx_edgelist.csv
# TxAddr_edgelist.csv
# txs_classes.csv
# txs_edgelist.csv
# txs_features.csv
# wallets_classes.csv
# wallets_features.csv
# wallets_features_classes_combined.csv

# %%
import os

project_path = r"C:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection"

os.makedirs(os.path.join(project_path, "data", "raw"), exist_ok=True)
os.makedirs(os.path.join(project_path, "data", "processed"), exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
import os

print(os.path.exists(
    r"C:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\data"
))

print(os.path.exists(
    r"C:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\data\raw"
))
# Out:
# True
# True

# %%
import shutil
import os

source = r"C:\Users\asus\Downloads\Elliptic++ Dataset"
destination = r"C:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\data\raw"

for file in os.listdir(source):
    if file.endswith(".csv"):
        shutil.copy2(
            os.path.join(source, file),
            os.path.join(destination, file)
        )

print("Dataset copied successfully!")
# Out:
# Dataset copied successfully!

# %%
import os

files = os.listdir(
    r"C:\Users\asus\Desktop\Elliptic++  project\Elliptic_Fraud_Detection\data\raw"
)

print("Number of files:", len(files))

for file in files:
    print(file)
# Out:
# Number of files: 8
# AddrTx_edgelist.csv
# TxAddr_edgelist.csv
# txs_classes.csv
# txs_edgelist.csv
# txs_features.csv
# wallets_classes.csv
# wallets_features.csv
# wallets_features_classes_combined.csv

# %%
import pandas as pd

tx_features = pd.read_csv(
    "../data/raw/txs_features.csv",
    nrows=5
)

print("Shape:", tx_features.shape)
tx_features.head()
# Out:
# Shape: (5, 184)
#     txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0   3321          1        -0.169615        -0.184668        -1.201369
# 1  11108          1        -0.137586        -0.184668        -1.201369
# 2  51816          1        -0.170103        -0.184668        -1.201369
# 3  68869          1        -0.114267        -0.184668        -1.201369
# 4  89273          1         5.202107        -0.210553        -1.756361
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.121970        -0.043875        -0.113002        -0.061584
# 1        -0.121970        -0.043875        -0.113002        -0.061584
# 2        -0.121970        -0.043875        -0.113002        -0.061584
# 3         0.028105        -0.043875        -0.113002         0.547008
# 4        -0.121970       260.090707        -0.113002        -0.061584
#
#    Local_feature_8  ...  in_BTC_min  in_BTC_max  in_BTC_mean  in_BTC_median  \
# ...

# %%
print(tx_features.columns.tolist())
# Out:
# ['txId', 'Time step', 'Local_feature_1', 'Local_feature_2', 'Local_feature_3', 'Local_feature_4', 'Local_feature_5', 'Local_feature_6', 'Local_feature_7', 'Local_feature_8', 'Local_feature_9', 'Local_feature_10', 'Local_feature_11', 'Local_feature_12', 'Local_feature_13', 'Local_feature_14', 'Local_feature_15', 'Local_feature_16', 'Local_feature_17', 'Local_feature_18', 'Local_feature_19', 'Local_feature_20', 'Local_feature_21', 'Local_feature_22', 'Local_feature_23', 'Local_feature_24', 'Local_feature_25', 'Local_feature_26', 'Local_feature_27', 'Local_feature_28', 'Local_feature_29', 'Local_feature_30', 'Local_feature_31', 'Local_feature_32', 'Local_feature_33', 'Local_feature_34', 'Local_feature_35', 'Local_feature_36', 'Local_feature_37', 'Local_feature_38', 'Local_feature_39', 'Local_feature_40', 'Local_feature_41', 'Local_feature_42', 'Local_feature_43', 'Local_feature_44', 'Local_feature_45', 'Local_feature_46', 'Local_feature_47', 'Local_feature_48', 'Local_feature_49', 'Loca
# ...

# %%
tx_classes = pd.read_csv(
    "../data/raw/txs_classes.csv"
)

print(tx_classes.shape)
tx_classes.head()
# Out:
# (203769, 2)
#     txId  class
# 0   3321      3
# 1  11108      3
# 2  51816      3
# 3  68869      2
# 4  89273      2

# %%
print(tx_classes['class'].value_counts())
# Out:
# class
# 3    157205
# 2     42019
# 1      4545
# Name: count, dtype: int64

# %%
tx_edges = pd.read_csv(
    "../data/raw/txs_edgelist.csv",
    nrows=5
)

print(tx_edges.shape)
tx_edges.head()
# Out:
# (5, 2)
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
tx_features.head()
tx_features.columns.tolist()

tx_classes.head()
tx_classes['class'].value_counts()

tx_edges.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
import networkx as nx

G = nx.from_pandas_edgelist(
    tx_edges,
    source='txId1',
    target='txId2',
    create_using=nx.DiGraph()
)

# %%
import pandas as pd

tx_features = pd.read_csv(
    "../data/raw/txs_features.csv",
    nrows=1000
)

print("Shape:", tx_features.shape)
print("\nColumns:")
print(tx_features.columns.tolist())

tx_features.head()
# Out:
# Shape: (1000, 184)
#
# Columns:
# ...

# %%
tx_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 184 entries, txId to out_BTC_total
# dtypes: float64(182), int64(2)
# memory usage: 1.4 MB

# %%
tx_features.describe()
# Out:
#                txId  Time step  Local_feature_1  Local_feature_2  \
# count  1.000000e+03     1000.0      1000.000000      1000.000000
# mean   7.366707e+06        1.0        -0.063122        -0.161687
# std    5.502156e+06        0.0         0.772495         0.132293
# min    3.321000e+03        1.0        -0.172981        -0.210553
# 25%    3.403500e+06        1.0        -0.172501        -0.184668
# 50%    4.744636e+06        1.0        -0.170881        -0.184668
# 75%    1.126219e+07        1.0        -0.159855        -0.184531
# max    2.201386e+07        1.0        16.114588         2.456149
#
#        Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# count      1000.000000      1000.000000      1000.000000      1000.000000
# mean         -0.826749         0.024354         0.251156         0.011953
# std           0.745258         0.980457         8.231041         0.875044
# min          -1.756361        -0.121970        -0.063725        -0.113002
# ...

# %%
tx_classes = pd.read_csv(
    "../data/raw/txs_classes.csv"
)

print(tx_classes.shape)
tx_classes.head()
# Out:
# (203769, 2)
#     txId  class
# 0   3321      3
# 1  11108      3
# 2  51816      3
# 3  68869      2
# 4  89273      2

# %%
print(tx_classes['class'].value_counts())
# Out:
# class
# 3    157205
# 2     42019
# 1      4545
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

tx_classes['class'].value_counts().plot(kind='bar')

plt.title("Transaction Class Distribution")
plt.show()

# %%
tx_edges = pd.read_csv(
    "../data/raw/txs_edgelist.csv"
)

print(tx_edges.shape)
tx_edges.head()
# Out:
# (234355, 2)
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
print(tx_edges.isnull().sum())
# Out:
# txId1    0
# txId2    0
# dtype: int64

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

G = nx.from_pandas_edgelist(
    tx_edges,
    source='txId1',
    target='txId2',
    create_using=nx.DiGraph()
)

print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
# Out:
# Nodes: 203769
# Edges: 234355

# %%
print("Density:", nx.density(G))
# Out:
# Density: 5.644170528459417e-06

# %%
degree_dict = dict(G.degree())

print("Max Degree:", max(degree_dict.values()))
print("Average Degree:", sum(degree_dict.values()) / len(degree_dict))
# Out:
# Max Degree: 473
# Average Degree: 2.3002026804862368

# %%
degree_centrality = nx.degree_centrality(G)

pagerank = nx.pagerank(
    G,
    alpha=0.85
)

# %%
graph_features = pd.DataFrame({
    'txId': list(degree_centrality.keys()),
    'degree_centrality': list(degree_centrality.values()),
    'pagerank': [pagerank[node] for node in degree_centrality.keys()]
})

graph_features.head()
# Out:
#         txId  degree_centrality  pagerank
# 0  230425980           0.000010  0.000005
# 1    5530458           0.000010  0.000006
# 2  232022460           0.000015  0.000007
# 3  232438397           0.000790  0.000351
# 4  230460314           0.000049  0.000002

# %%
tx_features = pd.read_csv("../data/raw/txs_features.csv")
tx_classes = pd.read_csv("../data/raw/txs_classes.csv")

master_df = tx_features.merge(
    tx_classes,
    on="txId",
    how="inner"
)

print(master_df.shape)
master_df.head()
# Out:
# (203769, 185)
#     txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0   3321          1        -0.169615        -0.184668        -1.201369
# 1  11108          1        -0.137586        -0.184668        -1.201369
# 2  51816          1        -0.170103        -0.184668        -1.201369
# 3  68869          1        -0.114267        -0.184668        -1.201369
# 4  89273          1         5.202107        -0.210553        -1.756361
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.121970        -0.043875        -0.113002        -0.061584
# 1        -0.121970        -0.043875        -0.113002        -0.061584
# 2        -0.121970        -0.043875        -0.113002        -0.061584
# 3         0.028105        -0.043875        -0.113002         0.547008
# 4        -0.121970       260.090707        -0.113002        -0.061584
#
#    Local_feature_8  ...  in_BTC_max  in_BTC_mean  in_BTC_median  in_BTC_total  \
# ...

# %%
master_df['class'].value_counts()
# Out:
# class
# 3    157205
# 2     42019
# 1      4545
# Name: count, dtype: int64

# %%
master_df = master_df[
    master_df['class'] != 'unknown'
]

# %%
degree_centrality = nx.degree_centrality(G)

# %%
pagerank = nx.pagerank(G)

# %%
graph_features = pd.DataFrame({
    'txId': list(degree_centrality.keys()),
    'degree_centrality': list(degree_centrality.values()),
    'pagerank': [pagerank[node] for node in degree_centrality.keys()]
})

graph_features.head()
# Out:
#         txId  degree_centrality  pagerank
# 0  230425980           0.000010  0.000005
# 1    5530458           0.000010  0.000006
# 2  232022460           0.000015  0.000007
# 3  232438397           0.000790  0.000351
# 4  230460314           0.000049  0.000002

# %%
master_df = master_df.merge(
    graph_features,
    on='txId',
    how='left'
)

master_df.head()
# Out:
#     txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0   3321          1        -0.169615        -0.184668        -1.201369
# 1  11108          1        -0.137586        -0.184668        -1.201369
# 2  51816          1        -0.170103        -0.184668        -1.201369
# 3  68869          1        -0.114267        -0.184668        -1.201369
# 4  89273          1         5.202107        -0.210553        -1.756361
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.121970        -0.043875        -0.113002        -0.061584
# 1        -0.121970        -0.043875        -0.113002        -0.061584
# 2        -0.121970        -0.043875        -0.113002        -0.061584
# 3         0.028105        -0.043875        -0.113002         0.547008
# 4        -0.121970       260.090707        -0.113002        -0.061584
#
#    Local_feature_8  ...  in_BTC_median  in_BTC_total   out_BTC_min  \
# ...
